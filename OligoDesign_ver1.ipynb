# %%
import pandas as pd

# Import OligoMiner modules.
# from oligodesigner import blockParse

from oligodesigner import io
from oligodesigner import parse
from oligodesigner import sequence
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [3], line 8
#       6 from oligodesigner import io
#       7 from oligodesigner import parse
# ----> 8 from oligodesigner import sequence
#
# File ~/src/split-oligo-designer/oligodesigner/sequence.py:1
# ----> 1 import mygene
#       2 from Bio.Blast.Applications import NcbiblastnCommandline
#       3 import pandas as pd
#
# ModuleNotFoundError: No module named 'mygene'

# %%
# Configs
# To make your database, see https://www.ncbi.nlm.nih.gov/books/NBK569841/

cdna_database = {
                 'human': '/mnt/heintz-bambi3/WORK/tmurakami/oligo/sequence/human_transcriptome/human_transcriptome_db',
                 'mouse': '/mnt/heintz-bambi3/WORK/tmurakami/oligo/sequence/mouse_transcriptome/mouse_transcriptome_db',
                 'rat'  : '/mnt/heintz-bambi3/WORK/tmurakami/oligo/sequence/rat_transcriptome/rat_transcriptome_db'
}


hcr_b_set = {
    'B1':{
        'splitseq_ll':'GAGGAGGGCAGCAAACGG','splitseq_rr':'GAAGAGTCTTCCTTTACG','anchorseq_ll':'aa','anchorseq_rr':'at',
        'splitseq_lr':'GGCAGCAAACGGGAAGAG','splitseq_rl':'GCATTCTTTCTTGAGGAG','anchorseq_lr':'tt','anchorseq_rl':'tt'
    },
    'B2':{
        'splitseq_ll':'CCTCGTAAATCCTCATCA','splitseq_rr':'ATCATCCAGTAAACCGCC','anchorseq_ll':'aa','anchorseq_rr':'aa',
        'splitseq_lr':'AAATCCTCATCAATCATC','splitseq_rl':'AGCTCAGTCCATCCTCGT','anchorseq_lr':'ta','anchorseq_rl':'ta'
    },
    'B3':{
        'splitseq_ll':'GTCCCTGCCTCTATATCT','splitseq_rr':'CCACTCAACTTTAACCCG','anchorseq_ll':'tt','anchorseq_rr':'tt',
        'splitseq_lr':'GCCTCTATATCTCCACTC','splitseq_rl':'AAAGTCTAATCCGTCCCT','anchorseq_lr':'ta','anchorseq_rl':'aa'
    },
    'B4':{
        'splitseq_ll':'CCTCAACCTACCTCCAAC','splitseq_rr':'TCTCACCATATTCGCTTC','anchorseq_ll':'aa','anchorseq_rr':'at',
        'splitseq_lr':'CCTACCTCCAACTCTCAC','splitseq_rl':'CACATTTACAGACCTCAA','anchorseq_lr':'tt','anchorseq_rl':'at'
    },
    'B5':{
        'splitseq_ll':'CTCACTCCCAATCTCTAT','splitseq_rr':'CTACCCTACAAATCCAAT','anchorseq_ll':'aa','anchorseq_rr':'aa',
        'splitseq_lr':'CCCAATCTCTATCTACCC','splitseq_rl':'CACTTCATATCACTCACT','anchorseq_lr':'at','anchorseq_rl':'aa'
    },
    'B8':{
        'splitseq_ll':'CCTTGATTATCTCGTCTC','splitseq_rr':'CATCACTCGCACTCTACC','anchorseq_ll':'at','anchorseq_rr':'aa',
        'splitseq_lr':'TCTACCGTCAAGTCAAAC','splitseq_rl':'CGTCTCCATCACTCGCAC','anchorseq_lr':'aa','anchorseq_rl':'aa'
    }
}

# %%
# Parameter settings
mFISH3D_param = {
    'input_file':'/mnt/heintz-bambi3/WORK/tmurakami/oligo/sequence/slc17a7_hs/HCRv3/slc17a7_hs.fasta',
    'hcr_bnum':'B1',
    'genename':'Slc17a7',
    'species':'human',
    'minimum_offtarget_gap':100,
    'oligo_number': 48
}

oligominer_param = {
    'l':20,
    'L':20,
    'gcPercent':25,
    'GCPercent':75,
    'tm':0,
    'TM':100,
    'X':'AAAAAA,TTTTTT,CCCCCC,GGGGGG',
    'sal':390,#default value of blockParse
    'form':30,
    'sp':1,
    'concA':25,#default value of blockParse
    'concB':25,#default value of blockParse
    'headerVal':None,
    'bedVal':False,
    'OverlapModeVal':False,
    'verbocity':False,
    'reportVal':True,
    'debugVal':False,
    'metaVal':False,
    'outNameVal':None,
    'nn_table':'DNA_NN3'
}

# %%
input_file = mFISH3D_param['input_file']
spiecies = mFISH3D_param['species']
transcriptomeDatabase = cdna_database[spiecies]
hcr_initiator_set = hcr_b_set[mFISH3D_param['hcr_bnum']]
genename = mFISH3D_param['genename']
minimum_offtarget_gap = mFISH3D_param['minimum_offtarget_gap']
oligo_number = mFISH3D_param['oligo_number']

# Make path to temp files and result file
(oligominer_fastq, oligominer_fasta, blast_result, oligo_sets, param_file) = io.gen_file_path(input_file)
# Save parameters to csv file.
io.record_param(mFISH3D_param, oligominer_param, param_file)

# %%
# Run OligoMiner
blockParse.runSequenceCrawler(input_file, *parse.oligominer_param_parser(oligominer_param))
# Out:
# 0 of 2949
# 132 candidate probes identified in 2.94 kb yielding 44.96 candidates/kb

# %%
geneinfo = sequence.fetch_mygene(genename, spiecies)
# Blast after converting fastq to fasta
io.convert_fastq2fasta(oligominer_fastq,oligominer_fasta)
io.add_id(oligominer_fasta)
'''Number of thread can be inserted as a blast parameter.'''
sequence.run_blast(oligominer_fasta,blast_result,transcriptomeDatabase)
# Read blast result file, exclude sequence which is homologous to the gene of interest from result
df_blast = sequence.exclude_self(io.read_blast(blast_result), geneinfo)
# Remove combination if sstart and send are close enough and if they are rective combination.
oligo_to_be_removed = sequence.get_off_targeting_oligo(minimum_offtarget_gap, df_blast)

# %%
oligominer_df = io.dataframe_from_oligominer(oligominer_fastq)
selected_oligo_df = sequence.remove_oligo(oligominer_df, oligo_to_be_removed)

interval = sequence.calc_oligo_interval(selected_oligo_df, oligo_number)
selected_oligo_df = pd.concat([selected_oligo_df,interval],axis=1)

# Make oligos with HCR sequences.
res = sequence.add_hcr_seq_v3(selected_oligo_df, hcr_initiator_set)
res.to_csv(oligo_sets, sep=',', index=False, header=True)

# %%
res
# Out:
#             gene         oligo_id  \
# 0    NM_020309.4    NM_020309.4_0
# 1    NM_020309.4    NM_020309.4_1
# 2    NM_020309.4    NM_020309.4_2
# 3    NM_020309.4    NM_020309.4_3
# 4    NM_020309.4    NM_020309.4_4
# 5    NM_020309.4    NM_020309.4_5
# 6    NM_020309.4    NM_020309.4_6
# 7    NM_020309.4    NM_020309.4_7
# 8    NM_020309.4    NM_020309.4_8
# 9    NM_020309.4    NM_020309.4_9
# 10   NM_020309.4   NM_020309.4_10
# 11   NM_020309.4   NM_020309.4_11
# 12   NM_020309.4   NM_020309.4_12
# 13   NM_020309.4   NM_020309.4_13
# 14   NM_020309.4   NM_020309.4_14
# 15   NM_020309.4   NM_020309.4_15
# 16   NM_020309.4   NM_020309.4_16
# 17   NM_020309.4   NM_020309.4_17
# 18   NM_020309.4   NM_020309.4_18
# 19   NM_020309.4   NM_020309.4_19
# 20   NM_020309.4   NM_020309.4_20
# 21   NM_020309.4   NM_020309.4_21
# 22   NM_020309.4   NM_020309.4_22
# 23   NM_020309.4   NM_020309.4_23
# 24   NM_020309.4   NM_020309.4_24
# 25   NM_020309.4   NM_020309.4_25
# 26   NM_020309.4   NM_020309.4_26
# 27   NM_020309.4   NM_020309.4_27
# 28   NM_020309.4   NM_020309.4_28
# 29   NM_020309.4   NM_020309.4_29
# ..           ...              ...
# 99   NM_020309.4  NM_020309.4_101
# 100  NM_020309.4  NM_020309.4_102
# 101  NM_020309.4  NM_020309.4_103
# 102  NM_020309.4  NM_020309.4_104
# 103  NM_020309.4  NM_020309.4_105
# 104  NM_020309.4  NM_020309.4_106
# 105  NM_020309.4  NM_020309.4_107
# 106  NM_020309.4  NM_020309.4_108
# 107  NM_020309.4  NM_020309.4_109
# 108  NM_020309.4  NM_020309.4_110
# 109  NM_020309.4  NM_020309.4_111
# 110  NM_020309.4  NM_020309.4_112
# 111  NM_020309.4  NM_020309.4_113
# 112  NM_020309.4  NM_020309.4_114
# 113  NM_020309.4  NM_020309.4_115
# 114  NM_020309.4  NM_020309.4_116
# 115  NM_020309.4  NM_020309.4_117
# 116  NM_020309.4  NM_020309.4_118
# 117  NM_020309.4  NM_020309.4_119
# 118  NM_020309.4  NM_020309.4_120
# 119  NM_020309.4  NM_020309.4_121
# 120  NM_020309.4  NM_020309.4_122
# 121  NM_020309.4  NM_020309.4_123
# 122  NM_020309.4  NM_020309.4_124
# 123  NM_020309.4  NM_020309.4_125
# 124  NM_020309.4  NM_020309.4_126
# 125  NM_020309.4  NM_020309.4_127
# 126  NM_020309.4  NM_020309.4_128
# 127  NM_020309.4  NM_020309.4_130
# 128  NM_020309.4  NM_020309.4_131
#
#                                                    seq  start   end  \
# 0    (A, C, T, T, G, C, A, G, C, C, T, C, C, T, T, ...      1    20
# 1    (T, G, G, A, C, C, C, C, G, G, G, A, A, C, C, ...     54    73
# 2    (C, G, G, C, A, G, G, A, G, C, C, G, C, C, A, ...    132   151
# 3    (A, G, T, T, C, C, G, C, C, A, G, G, A, G, G, ...    153   172
# 4    (G, G, A, A, G, C, T, A, G, C, G, G, G, T, C, ...    174   193
# 5    (T, C, G, G, G, A, A, G, C, T, G, C, A, C, C, ...    195   214
# 6    (T, G, G, A, G, A, A, G, C, G, G, C, A, G, G, ...    216   235
# 7    (C, G, G, A, G, A, C, G, C, T, G, G, A, G, C, ...    237   256
# 8    (G, A, T, G, G, G, C, G, C, C, C, G, G, T, G, ...    260   279
# 9    (G, G, A, C, C, C, G, C, C, G, G, T, G, G, T, ...    289   308
# 10   (C, A, C, C, T, G, C, T, T, C, G, G, C, C, T, ...    310   329
# 11   (C, C, G, C, T, A, C, A, T, T, A, T, C, G, C, ...    331   350
# 12   (G, A, G, T, G, G, T, C, T, G, G, G, C, T, T, ...    352   371
# 13   (C, A, G, C, T, T, T, G, G, C, A, T, C, C, G, ...    373   392
# 14   (C, C, T, G, G, G, C, G, T, G, G, C, C, A, T, ...    394   413
# 15   (C, A, T, G, G, T, C, A, A, T, A, A, C, A, G, ...    415   434
# 16   (G, G, G, G, C, C, A, C, G, T, G, G, T, G, G, ...    444   463
# 17   (A, A, G, C, C, C, A, G, T, T, C, A, G, C, T, ...    465   484
# 18   (C, A, G, A, G, A, C, T, G, T, C, G, G, C, C, ...    486   505
# 19   (A, C, G, G, C, T, C, C, T, T, T, T, T, C, T, ...    507   526
# 20   (A, C, A, T, T, G, T, C, A, C, T, C, A, G, A, ...    528   547
# 21   (G, A, G, G, A, T, T, T, A, T, C, T, G, T, C, ...    549   568
# 22   (T, T, G, C, A, G, C, C, A, A, C, A, G, A, G, ...    570   589
# 23   (G, C, T, T, T, G, C, T, A, T, T, G, T, G, G, ...    591   610
# 24   (C, C, A, C, T, C, T, A, A, A, C, A, T, G, C, ...    612   631
# 25   (C, C, T, C, A, G, C, T, G, C, C, C, G, C, G, ...    633   652
# 26   (A, T, G, G, C, T, G, T, G, T, C, A, T, C, T, ...    654   673
# 27   (G, G, A, T, C, C, T, G, C, A, G, G, G, G, T, ...    675   694
# 28   (A, G, G, G, G, G, T, C, A, C, A, T, A, C, C, ...    696   715
# 29   (G, C, C, A, T, G, G, G, A, T, C, T, G, G, A, ...    717   736
# ..                                                 ...    ...   ...
# 99   (T, C, T, C, T, C, C, C, A, A, C, T, C, T, G, ...   2273  2292
# 100  (A, T, C, T, T, C, C, A, G, A, T, T, G, G, T, ...   2294  2313
# 101  (A, A, T, T, A, C, T, C, G, T, C, C, C, C, G, ...   2315  2334
# 102  (C, A, G, G, G, A, T, T, G, A, T, T, C, T, C, ...   2336  2355
# 103  (G, T, T, T, C, T, G, A, T, G, G, A, A, A, A, ...   2357  2376
# 104  (T, T, T, C, A, A, G, T, C, C, C, C, G, A, T, ...   2378  2397
# 105  (C, C, C, A, C, T, T, C, A, C, A, T, C, T, C, ...   2399  2418
# 106  (C, A, G, C, A, G, A, T, T, C, T, G, C, G, A, ...   2420  2439
# 107  (C, A, A, A, T, T, T, C, T, C, A, A, G, A, C, ...   2441  2460
# 108  (C, T, C, C, C, T, A, G, C, T, T, A, G, C, A, ...   2462  2481
# 109  (C, T, G, G, G, G, A, A, A, C, A, A, C, C, A, ...   2483  2502
# 110  (C, A, A, T, T, T, T, A, A, C, A, A, T, A, T, ...   2504  2523
# 111  (C, T, A, C, C, C, C, C, G, T, G, C, A, C, T, ...   2525  2544
# 112  (G, A, C, A, T, G, G, T, T, T, T, C, A, G, G, ...   2546  2565
# 113  (T, A, G, T, G, G, C, T, G, C, T, C, C, A, G, ...   2567  2586
# 114  (A, A, C, T, C, A, A, A, G, G, T, T, T, G, A, ...   2588  2607
# 115  (C, A, C, C, A, T, T, G, A, A, C, T, C, C, C, ...   2609  2628
# 116  (T, G, G, T, T, T, C, A, T, G, A, T, G, C, C, ...   2630  2649
# 117  (C, C, A, A, T, T, C, C, T, C, G, C, A, C, T, ...   2651  2670
# 118  (T, C, C, T, G, G, G, T, G, G, T, T, T, C, G, ...   2672  2691
# 119  (C, C, T, G, T, T, T, C, T, C, A, G, T, G, G, ...   2693  2712
# 120  (G, T, T, G, T, G, T, C, C, C, T, C, A, G, G, ...   2714  2733
# 121  (A, T, G, A, C, T, C, A, A, A, A, T, C, T, G, ...   2735  2754
# 122  (T, T, C, C, C, C, T, C, T, C, A, G, A, C, A, ...   2756  2775
# 123  (T, T, T, C, A, G, C, T, T, A, G, A, A, T, T, ...   2777  2796
# 124  (A, C, C, T, A, T, A, G, A, G, A, A, G, T, C, ...   2798  2817
# 125  (T, C, C, C, A, T, G, A, A, A, G, G, G, A, A, ...   2819  2838
# 126  (T, T, T, T, T, C, C, C, A, G, T, G, C, A, G, ...   2855  2874
# 127  (T, G, A, C, T, G, T, A, A, A, T, C, C, T, G, ...   2897  2916
# 128  (C, C, C, A, C, T, C, C, C, A, A, T, A, A, A, ...   2918  2937
#
#      interval_after  mean_interval  \
# 0              34.0            NaN
# 1              59.0            NaN
# 2               2.0            NaN
# 3               2.0            NaN
# 4               2.0            NaN
# 5               2.0            NaN
# 6               2.0            NaN
# 7               4.0            NaN
# 8              10.0            NaN
# 9               2.0            NaN
# 10              2.0            NaN
# 11              2.0            NaN
# 12              2.0            NaN
# 13              2.0            NaN
# 14              2.0            NaN
# 15             10.0            NaN
# 16              2.0            NaN
# 17              2.0            NaN
# 18              2.0            NaN
# 19              2.0            NaN
# 20              2.0            NaN
# 21              2.0            NaN
# 22              2.0            NaN
# 23              2.0            NaN
# 24              2.0            NaN
# 25              2.0            NaN
# 26              2.0            NaN
# 27              2.0            NaN
# 28              2.0            NaN
# 29              2.0            NaN
# ..              ...            ...
# 99              2.0       3.750000
# 100             2.0       3.750000
# 101             2.0       3.750000
# 102             2.0       3.750000
# 103             2.0       3.750000
# 104             2.0       3.750000
# 105             2.0       3.750000
# 106             2.0       3.750000
# 107             2.0       3.750000
# 108             2.0       3.750000
# 109             2.0       3.750000
# 110             2.0       3.750000
# 111             2.0       3.750000
# 112             2.0       3.750000
# 113             2.0       3.750000
# 114             2.0       3.750000
# 115             2.0       3.750000
# 116             2.0       3.750000
# 117             2.0       3.750000
# 118             2.0       3.750000
# 119             2.0       3.750000
# 120             2.0       3.750000
# 121             2.0       3.312500
# 122             2.0       3.312500
# 123             2.0       3.312500
# 124             2.0       2.812500
# 125            17.0       2.083333
# 126            23.0       2.395833
# 127             2.0       2.833333
# 128             NaN       2.833333
#
#                                                hcr_seq
# 0    (G, A, G, G, A, G, G, G, C, A, G, C, A, A, A, ...
# 1    (G, C, A, T, T, C, T, T, T, C, T, T, G, A, G, ...
# 2    (G, A, G, G, A, G, G, G, C, A, G, C, A, A, A, ...
# 3    (G, C, A, T, T, C, T, T, T, C, T, T, G, A, G, ...
# 4    (G, A, G, G, A, G, G, G, C, A, G, C, A, A, A, ...
# 5    (G, C, A, T, T, C, T, T, T, C, T, T, G, A, G, ...
# 6    (G, A, G, G, A, G, G, G, C, A, G, C, A, A, A, ...
# 7    (G, C, A, T, T, C, T, T, T, C, T, T, G, A, G, ...
# 8    (G, A, G, G, A, G, G, G, C, A, G, C, A, A, A, ...
# 9    (G, C, A, T, T, C, T, T, T, C, T, T, G, A, G, ...
# 10   (G, A, G, G, A, G, G, G, C, A, G, C, A, A, A, ...
# 11   (G, C, A, T, T, C, T, T, T, C, T, T, G, A, G, ...
# 12   (G, A, G, G, A, G, G, G, C, A, G, C, A, A, A, ...
# 13   (G, C, A, T, T, C, T, T, T, C, T, T, G, A, G, ...
# 14   (G, A, G, G, A, G, G, G, C, A, G, C, A, A, A, ...
# 15   (G, C, A, T, T, C, T, T, T, C, T, T, G, A, G, ...
# 16   (G, A, G, G, A, G, G, G, C, A, G, C, A, A, A, ...
# 17   (G, C, A, T, T, C, T, T, T, C, T, T, G, A, G, ...
# 18   (G, A, G, G, A, G, G, G, C, A, G, C, A, A, A, ...
# 19   (G, C, A, T, T, C, T, T, T, C, T, T, G, A, G, ...
# 20   (G, A, G, G, A, G, G, G, C, A, G, C, A, A, A, ...
# 21   (G, C, A, T, T, C, T, T, T, C, T, T, G, A, G, ...
# 22   (G, A, G, G, A, G, G, G, C, A, G, C, A, A, A, ...
# 23   (G, C, A, T, T, C, T, T, T, C, T, T, G, A, G, ...
# 24   (G, A, G, G, A, G, G, G, C, A, G, C, A, A, A, ...
# 25   (G, C, A, T, T, C, T, T, T, C, T, T, G, A, G, ...
# 26   (G, A, G, G, A, G, G, G, C, A, G, C, A, A, A, ...
# 27   (G, C, A, T, T, C, T, T, T, C, T, T, G, A, G, ...
# 28   (G, A, G, G, A, G, G, G, C, A, G, C, A, A, A, ...
# 29   (G, C, A, T, T, C, T, T, T, C, T, T, G, A, G, ...
# ..                                                 ...
# 99   (G, C, A, T, T, C, T, T, T, C, T, T, G, A, G, ...
# 100  (G, A, G, G, A, G, G, G, C, A, G, C, A, A, A, ...
# 101  (G, C, A, T, T, C, T, T, T, C, T, T, G, A, G, ...
# 102  (G, A, G, G, A, G, G, G, C, A, G, C, A, A, A, ...
# 103  (G, C, A, T, T, C, T, T, T, C, T, T, G, A, G, ...
# 104  (G, A, G, G, A, G, G, G, C, A, G, C, A, A, A, ...
# 105  (G, C, A, T, T, C, T, T, T, C, T, T, G, A, G, ...
# 106  (G, A, G, G, A, G, G, G, C, A, G, C, A, A, A, ...
# 107  (G, C, A, T, T, C, T, T, T, C, T, T, G, A, G, ...
# 108  (G, A, G, G, A, G, G, G, C, A, G, C, A, A, A, ...
# 109  (G, C, A, T, T, C, T, T, T, C, T, T, G, A, G, ...
# 110  (G, A, G, G, A, G, G, G, C, A, G, C, A, A, A, ...
# 111  (G, C, A, T, T, C, T, T, T, C, T, T, G, A, G, ...
# 112  (G, A, G, G, A, G, G, G, C, A, G, C, A, A, A, ...
# 113  (G, C, A, T, T, C, T, T, T, C, T, T, G, A, G, ...
# 114  (G, A, G, G, A, G, G, G, C, A, G, C, A, A, A, ...
# 115  (G, C, A, T, T, C, T, T, T, C, T, T, G, A, G, ...
# 116  (G, A, G, G, A, G, G, G, C, A, G, C, A, A, A, ...
# 117  (G, C, A, T, T, C, T, T, T, C, T, T, G, A, G, ...
# 118  (G, A, G, G, A, G, G, G, C, A, G, C, A, A, A, ...
# 119  (G, C, A, T, T, C, T, T, T, C, T, T, G, A, G, ...
# 120  (G, A, G, G, A, G, G, G, C, A, G, C, A, A, A, ...
# 121  (G, C, A, T, T, C, T, T, T, C, T, T, G, A, G, ...
# 122  (G, A, G, G, A, G, G, G, C, A, G, C, A, A, A, ...
# 123  (G, C, A, T, T, C, T, T, T, C, T, T, G, A, G, ...
# 124  (G, A, G, G, A, G, G, G, C, A, G, C, A, A, A, ...
# 125  (G, C, A, T, T, C, T, T, T, C, T, T, G, A, G, ...
# 126  (G, A, G, G, A, G, G, G, C, A, G, C, A, A, A, ...
# 127  (G, C, A, T, T, C, T, T, T, C, T, T, G, A, G, ...
# 128  (G, A, G, G, A, G, G, G, C, A, G, C, A, A, A, ...
#
# [129 rows x 8 columns]
